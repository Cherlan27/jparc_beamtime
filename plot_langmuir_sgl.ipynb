# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

langmuir_data = open('langmuir/test030601_05_fr121_d62DPPC_trans.apd', mode="r")

# %%
data = langmuir_data.readline()

# %%
pressure = []
location = []

data_sep = data.split(";")

for row in data_sep:
    values = row.split(",")
    pressure.append(float(values[5]))
    location.append(float(values[8]))
location = np.array(location)
pressure = np.array(pressure)

# %%
area = (255.87 - location)*80

# %%
fig = plt.figure()
ax = fiｇ.gca()
ax.plot(area, pressure)
ax.set_ylabel("Pressure")
ax.set_xlabel("Area")
ax.axhline(y=12, color = "red")
ax.axhline(y=15, color = "red")
ax.axhline(y=18, color = "red")
plt.show()
