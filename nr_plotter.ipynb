# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv("Z:/RajendraGiri/2023Jun/FR121_d62DPPC_12mN_trans_D2Obuffer_04deg_all_RQz.dat"  , sep="\t")
values = np.array(df)
qz = values[:,0]
intensities = values[:,1]
intensities_err = values[:,2]

# %%
def fresnel(qz,qc = 0.018, roughness=2.4):
    return (np.exp(-qz**2 * roughness**2) *
            abs((qz - np.sqrt((qz**2 - qc**2) + 0j)) /
            (qz + np.sqrt((qz**2 - qc**2)+0j)))**2)

# %%
fig = plt.figure()
ax = fiｇ.gca()
ax.errorbar(qz, intensities, intensities_err)
ax.plot(qz, fresnel(qz), linestyle = "--", color = "black")
ax.set_yscale("log")
ax.set_ylabel("R")
ax.set_xlabel("qz in 1/A")
plt.show()
